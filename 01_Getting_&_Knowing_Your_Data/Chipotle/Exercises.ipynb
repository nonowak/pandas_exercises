# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep="\t")

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
len(chipo)
# Out:
# 4622

# %%
# Solution 2
chipo.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
most_ordered_item = chipo.groupby('item_name').sum().nlargest(1, ['quantity'])
most_ordered_item.index
# Out:
# Index(['Chicken Bowl'], dtype='object', name='item_name')

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
most_ordered_item['quantity']
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
most_ordered_item = chipo.groupby('choice_description').sum().nlargest(1, ['quantity'])
most_ordered_item.index
# Out:
# Index(['[Diet Coke]'], dtype='object', name='choice_description')

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo.sum().quantity
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:-1]))

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']

'Revenue: $%.2f'%sum(chipo['revenue'])
# Out:
# 'Revenue: $39237.02'

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
len(chipo['order_id'].unique())
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
chipo.groupby('order_id').apply(lambda x: sum(x['revenue']).mean()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description  item_price  revenue
# 0                NaN        2.39     2.39
# 1       [Clementine]        3.39     3.39
# 2            [Apple]        3.39     3.39
# 3                NaN        2.39     2.39
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description  item_price  revenue
# 0                NaN        2.39     2.39
# 1       [Clementine]        3.39     3.39
# ...

# %%
# Solution 2
chipo.groupby('order_id').sum().mean()['revenue']
# Out:
# 21.394231188658654

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
len(chipo['item_name'].unique())
# Out:
# 50
